# %% [markdown]
# # Importing Data 🗂️

# %% [markdown]
# ## Data Import - general notions

# %%
# Install pandas
# !pip install pandas

# %%
# Import pandas and Read the iris dataset from a CSV file
import pandas as pd

df = pd.read_csv('/content/iris.data', header = None)

df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
# Set column names
df = pd.read_csv('/content/iris.data', header = None, names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'] )

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Set column names using a variable

column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

df = pd.read_csv('/content/iris.data', header = None, names= column_names)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Read data from a JSON file
df_json = pd.read_json('https://jsonplaceholder.typicode.com/posts')

df_json.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
# Read data from an Excel file
df_xls = pd.read_excel('/content/file_example_XLS_50.xls', index_col = 0)

df_xls.head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0
# 1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3     Philip       Gent    Male         France   36  21/05/2015  2587
# 4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %% [markdown]
# ### Challenge 🚀

# %%
# Import grade.csv and show the first rows
import pandas as pd

df_grades = pd.read_csv('/content/grades.csv')

df_grades.head()
# Out:
#   Last name      "First name"                 "SSN"         "Test1"   "Test2"  \
# 0   Alfalfa        "Aloysius"         "123-45-6789"            40.0      90.0
# 1    Alfred      "University"         "123-12-1234"            41.0      97.0
# 2     Gerty          "Gramma"         "567-89-0123"            41.0      80.0
# 3   Android        "Electric"         "087-65-4321"            42.0      23.0
# 4   Bumpkin            "Fred"         "456-78-9012"            43.0      78.0
#
#     "Test3"   "Test4"   "Final"  "Grade"
# 0     100.0      83.0      49.0     "D-"
# 1      96.0      97.0      48.0     "D+"
# 2      60.0      40.0      44.0      "C"
# 3      36.0      45.0      47.0     "B-"
# 4      88.0      77.0      45.0     "A-"

# %% [markdown]
# ## Colab Data Import

# %%
# Linking Google Drive for data access
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_drive = pd.read_excel('/content/drive/MyDrive/Temp - Data Analysis - David/file_example_XLS_50.xls')

df_drive.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %% [markdown]
# ### Challenge 🚀

# %%
# Import the iris dataset to Google Drive and display the first rows

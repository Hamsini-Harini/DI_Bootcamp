# %% [markdown]
# **EXERCISES **

# %% [markdown]
# TASK 1
#
# What is Data Analysis?
# Data analysis is the process of cleaning, transforming, and interpreting data to uncover useful insights. It helps make sense of large amounts of information, turning it into actionable knowledge. DA can be split in 4 different analysis types:
#
# Descriptive Analysis: Understanding past data.
# Predictive Analysis: Forecasting future trends.
# Prescriptive Analysis: Recommending actions based on data.
#
# Why is Data Analysis Important?
# Data analysis is crucial in today’s digital world due to:
#
# Informed Decision-Making: It helps businesses base decisions on evidence and trends rather than guesses.
# Increased Efficiency: Identifying inefficiencies and optimizing resources through data.
# Competitive Advantage: Companies that utilize data stay ahead by understanding markets, customers, and trends faster than competitors.
# Areas Where Data Analysis is Applied
#
# Healthcare:
# Predict disease outbreaks, personalize treatment plans, and optimize hospital operations.
# Example: During COVID-19, data helped track the virus and optimize vaccine distribution.
#
# Finance:
# Manage risks, detect fraud, and improve investment strategies.
# Example: Banks use algorithms to detect fraud and assess credit risk.
#
# Retail/E-commerce:
# Personalize customer experiences, adjust pricing, and manage inventory efficiently.
# Example: Amazon analyzes customer behavior to recommend products and optimize stock.
#
# Public sector:
# What kinds of laws should we enact - based on what data.
# Or another use case would be improving urban living - for example identifying places which need more parking lots etc...

# %%
# !pip install kaggle

# Upload kaggle.json file (Run this cell and select your kaggle.json file through the file picker)
from google.colab import files
uploaded = files.upload()

# Make directory named kaggle and copy kaggle.json file there
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# Change the permissions of the file
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# ...
#      <input type="file" id="files-bf2736d7-1648-44d7-9ad5-6af74e0807bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf2736d7-1648-44d7-9ad5-6af74e0807bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d thedevastator/how-much-sleep-do-americans-really-get
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/how-much-sleep-do-americans-really-get
# License(s): copyright-authors
# ...
#   0% 0.00/7.62k [00:00<?, ?B/s]
# 100% 7.62k/7.62k [00:00<00:00, 19.5MB/s]

# %%
# !unzip how-much-sleep-do-americans-really-get.zip
# Out:
# Archive:  how-much-sleep-do-americans-really-get.zip
#   inflating: Time Americans Spend Sleeping.csv

# %%
import pandas as pd
db_sleep = pd.read_csv('Time Americans Spend Sleeping.csv')
db_sleep.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
db_sleep.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %% [markdown]
# So now we're repeating the same process for the following 2 files. After you've set up your API, we need to:
# 1. Download the dataset
# 2. Unzip it
# 3. Load the dataset into Pandas DataFrame

# %%
# !kaggle datasets download -d thedevastator/uncover-global-trends-in-mental-health-disorder
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/uncover-global-trends-in-mental-health-disorder
# License(s): other
# ...
#  81% 1.00M/1.24M [00:00<00:00, 2.01MB/s]
# 100% 1.24M/1.24M [00:00<00:00, 2.39MB/s]

# %%
# !unzip uncover-global-trends-in-mental-health-disorder.zip
# Out:
# Archive:  uncover-global-trends-in-mental-health-disorder.zip
#   inflating: Mental health Depression disorder Data.csv

# %%
db_mental_disorder = pd.read_csv('Mental health Depression disorder Data.csv')
db_mental_disorder.head()
# Out:
# <ipython-input-25-8a648d2ab08a>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   db_mental_disorder = pd.read_csv('Mental health Depression disorder Data.csv')
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# ...

# %%
db_mental_disorder.describe()
# Out:
#                index  Anxiety disorders (%)  Drug use disorders (%)  \
# count  108553.000000            6468.000000             6468.000000
# mean    54276.000000               3.989921                0.862278
# std     31336.696223               1.167526                0.460679
# min         0.000000               2.023393                0.383650
# 25%     27138.000000               3.188824                0.535064
# 50%     54276.000000               3.554373                0.726430
# 75%     81414.000000               4.682163                0.940157
# max    108552.000000               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)
# count     6468.000000                6468.000000
# mean         3.497654                   1.585821
# std          0.655859                   0.860283
# min          2.139903                   0.446940
# 25%          3.005529                   0.993685
# 50%          3.499606                   1.479936
# ...

# %%
# !kaggle datasets download -d samuelcortinhas/credit-card-approval-clean-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/samuelcortinhas/credit-card-approval-clean-data
# License(s): CC0-1.0
# ...
#   0% 0.00/19.0k [00:00<?, ?B/s]
# 100% 19.0k/19.0k [00:00<00:00, 40.6MB/s]

# %%
# !unzip credit-card-approval-clean-data.zip
# Out:
# Archive:  credit-card-approval-clean-data.zip
#   inflating: clean_dataset.csv
#   inflating: crx.csv

# %%
db_cc_approval = pd.read_csv('clean_dataset.csv')
db_cc_approval.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
db_cc_approval.describe()
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %% [markdown]
# Exercise 4

# %%
#Download the Iris dataset from Kaggle using the API
# !kaggle datasets download -d saurabh00007/iriscsv

# Unzip the dataset
# !unzip iriscsv.zip

# Load the dataset into a Pandas DataFrame
db_iris = pd.read_csv('Iris.csv')

# Display the first few rows of the dataset
db_iris.head()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/saurabh00007/iriscsv
# License(s): CC0-1.0
# ...
#   0% 0.00/1.28k [00:00<?, ?B/s]
# 100% 1.28k/1.28k [00:00<00:00, 3.66MB/s]
# Archive:  iriscsv.zip
#   inflating: Iris.csv
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
qualitative_columns = db_iris.select_dtypes(include=['object']).columns
print(qualitative_columns)
# Out:
# Index(['Species'], dtype='object')

# %%
quantitative_columns = db_iris.select_dtypes(include=['float64', 'int64']).columns
print(quantitative_columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis with Google Colab
#
#
# Objective: Perform basic data analysis using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :
# import matplotlib.pyplot as plt
# plt.plot(data['Name_column1'], data['Name_column2'])
# plt.show()
# Document your findings in the notebook.
# Tools: Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.

# %% [markdown]
# I choose to operate on SepalLengthCm cell

# %%
# Mean
mean_sepal_length = db_iris['SepalLengthCm'].mean()
print(f"Mean of Sepal Length: {mean_sepal_length}")

# Median
median_sepal_length = db_iris['SepalLengthCm'].median()
print(f"Median of Sepal Length: {median_sepal_length}")

# Mode)
mode_sepal_length = db_iris['SepalLengthCm'].mode()[0]  # Get the first mode in case of multiple modes
print(f"Mode of Sepal Length: {mode_sepal_length}")
# Out:
# Mean of Sepal Length: 5.843333333333334
# Median of Sepal Length: 5.8
# Mode of Sepal Length: 5.0

# %%
import matplotlib.pyplot as plt

# Create a histogram of the 'SepalLengthCm' column
plt.figure(figsize=(8, 6))
plt.hist(db_iris['SepalLengthCm'], bins=10, color='blue', edgecolor='black')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The distribution is not normal, it looks skewed to the left, having 2 or 3 peaks, indicating that we might have diffeerent (sub)species in our database

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills in Data Analysis
#
#
# Objective: Develop observation skills for data analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %% [markdown]
# Here are some of the things/trends we can look into:
# 1. What is the average number of sleep hours from 2003 to date?
# 2. Who sleeps more, men or women?
# 3. Do older people really sleep less?
# 4. Do people sleep more on weekends?

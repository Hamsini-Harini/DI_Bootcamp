# %% [markdown]
# #Exercise 1: Identifying Data Types
#
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# A company’s financial reports stored in an Excel file. - structured
#
# Photographs uploaded to a social media platform - unstructured.
#
# A collection of news articles on a website - unstructured.
#
# Inventory data in a relational database - structured.
#
# Recorded interviews from a market research study. - unstructured

# %% [markdown]
# #🌟 Exercise 2: Transformation Exercise
#
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# A series of blog posts about travel experiences - I suppose some form of NLP is needed to unlock the content and then create a tabular structure (for example the following can be the columns: location, date, sentiment)
#
# Audio recordings of customer service calls - convert speech to text to transcribe the recordings in to text. Then after analyzing the transcriptions, try to structure the data - calll ID, customer issue, resolved? etc...
#
# Handwritten notes from a brainstorming session - needs OCR first and once there's digital text then structure.
#
# A video tutorial on cooking. Make transcription and try to identify key moments of a video to grasp the topic, length, author, date and the recepy itself.

# %% [markdown]
# #🌟 Exercise 3: Application Scenario
#
# You are a data analyst at a retail company. You have access to various data sources, including transaction records, customer feedback comments, social media posts about your brand, and employee work schedules.
#
# Categorize each of these data sources as structured or unstructured.
# Suggest how you might use each type of data for improving the company’s business operations.

# %% [markdown]
# 1. Transaction records
# Structured data
# Analyze transaction records to identify sales trends, popular products, peak shopping times, bundled products etc. This data can help optimize inventory management, pricing strategies, and promotional campaigns.
#
# 2. Customer Feedback Comments
# Unstructured data
# Can be used to identify common complaints, product preferences, or service issues.
#
# 3. Social Media Posts About Your Brand
# Unstructured Data
# The only usecase comming to my mind is analyzing brand sentiment / brand perception

# %% [markdown]
# #🌟 Exercise 4 : Import a file from Kaggle
# Import the titanic dataset that you can find on Kaggle.
# Print the first few rows of the DataFrame.

# %%
# !pip install kaggle
from google.colab import files
files.upload()  # Upload the kaggle.json file which is API data basically
# Out:
# ...
#      <input type="file" id="files-af2cd90c-0da4-4270-b485-2eabec550b07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af2cd90c-0da4-4270-b485-2eabec550b07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# After uploading, move it to the right directory
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
#We finished with API, now we can communicate to Kaggle so let's downlod the file and make it a dataframe (it's CSV)
# !kaggle datasets download -d brendan45774/test-file
# !unzip test-file.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/brendan45774/test-file
# License(s): CC0-1.0
# test-file.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  test-file.zip
#   inflating: tested.csv

# %%
import pandas as pd
df = pd.read_csv('tested.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# #🌟 Exercise 5: Importing a CSV File
# Use the Iris Dataset CSV.
#
# Download the Iris dataset CSV file and place it in the same directory as your Jupyter Notebook.
# Import the CSV file using Pandas.
# Display the first five rows of the dataset.

# %%
from google.colab import files
db_iris = files.upload()
# Out:
#      <input type="file" id="files-c94cf324-d4f8-45e9-90b0-e3211738da80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c94cf324-d4f8-45e9-90b0-e3211738da80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Now that the file is uploaded, you can load it into a Pandas DataFrame
# The CSV file has no column names so I am going to name them

import pandas as pd

column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df = pd.read_csv('iris.data', header=None, names=column_names)

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import os

# Get the current working directory
cwd = os.getcwd()
print("Current Working Directory:", cwd)
# Out:
# Current Working Directory: /content

# %% [markdown]
# #🌟 Exercise 6 : Export a dataframe to excel format and JSON format.
# Create a simple dataframe.
# Export the dataframe to an excel file.
# Export the dataframe to a JSON file.

# %%
import pandas as pd

# Creating a simple DataFrame
data = {
    'Product': ['Widget A', 'Widget B', 'Gadget C', 'Gizmo D'],
    'Price': [19.99, 24.99, 14.99, 29.99],
    'Quantity': [100, 150, 200, 120],
    'Category': ['Tools', 'Tools', 'Gadgets', 'Gadgets']
}

df = pd.DataFrame(data)
df.head()
# Out:
#     Product  Price  Quantity Category
# 0  Widget A  19.99       100    Tools
# 1  Widget B  24.99       150    Tools
# 2  Gadget C  14.99       200  Gadgets
# 3   Gizmo D  29.99       120  Gadgets

# %%
df.to_excel('products.xlsx', index = False)
df.to_json('products.json', indent = 4)

# %% [markdown]
# #🌟 Exercise 7: Reading JSON Data
# Use a sample JSON dataset
#
# Import the JSON data from the provided URL.
# Use Pandas to read the JSON data.
# Display the first five entries of the data.

# %% [markdown]
# Even though there is an option to directly read (load) JSON from URL, the "correct" way to do it via requests library to fetch URL which will give you more possibilites (error handling, processing JSON before loading it, inspecting before loading etc).
#
# Direct Method (pd.read_json() or pd.read_csv()): Use this when the data is clean and can be directly interpreted by Pandas, which is often the case with simple APIs or straightforward CSV/JSON files.

# %%
# Directly read the JSON data from the URL into a DataFrame
url = 'https://jsonplaceholder.typicode.com/posts'
df = pd.read_json(url)

# Display the first five entries of the data
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
import requests

# Step 1: Import the JSON data from the provided URL
url = 'https://jsonplaceholder.typicode.com/posts'
response = requests.get(url)
json_data = response.json()

# Step 2: Use Pandas to read the JSON data
df = pd.DataFrame(json_data)

# Step 3: Display the first five entries of the data
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

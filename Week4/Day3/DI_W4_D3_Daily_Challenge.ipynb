# %% [markdown]
# #Your Task
# Load and Visualize Images using the Flower Color Images dataset
# Rotate an image by 90 degrees
# Flip an image horizontally and then vertically.
# Zoom in on an image (scale by 1.2x) using .resize(...)
# Display the original and augmented images side by side for comparison using this function :
#
#
# import matplotlib.pyplot as plt
# from PIL import Image, ImageOps
#
# def show_images(original, augmented, title):
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.imshow(original)
# plt.title('Original Image')
# plt.axis('off')
#
# plt.subplot(1, 2, 2)
# plt.imshow(augmented)
# plt.title(title)
# plt.axis('off')
#
# plt.show()

# %%
# !pip install pillow
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
# Upload Kaggle API key = json file
from google.colab import files
files.upload()

# Move the file to the right folder and give permissions
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download the dataset
# !kaggle datasets download -d olgabelitskaya/flower-color-images
# !unzip flower-color-images.zip
# Out:
#      <input type="file" id="files-519ffd56-f959-4f87-b3ff-430825290b22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-519ffd56-f959-4f87-b3ff-430825290b22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load an image using PIL
image_path = 'flowers/flowers/19_010.png'
original_image = Image.open(image_path)

# Display the original image using matplotlib
plt.imshow(original_image)
# additional commands can be added here to display image with title, remove axis etc

# %%
#rotating the image X number of degrees
rotated_image = original_image.rotate(90)
plt.imshow(rotated_image)

# %%
# Flip the image vertically = MIRROR
flipped_v = ImageOps.mirror(original_image)
plt.imshow(flipped_v)

# %%
# Flip the image horizontaly = FLIP function
flipped_h = ImageOps.flip(original_image)
plt.imshow(flipped_h)

# %%
# Zoom in on the image (scale by 1.5x)
width, height = original_image.size
zoomed_image = original_image.resize((int(width * 1.5), int(height * 1.5)))
plt.imshow(zoomed_image)

# %%
def show_images(original: Image.Image, augmented: Image.Image, title: str) -> None:
    """
    Display the original and augmented images side by side.

    Args:
    - original (Image.Image): The original image.
    - augmented (Image.Image): The augmented image.
    - title (str): The title for the augmented image.
    """
    plt.figure(figsize=(12, 6))

    # Display the original image
    plt.subplot(1, 2, 1)
    plt.imshow(original)
    plt.title('Original Image')
    plt.axis('off')  # Hide axes for clarity

    # Display the augmented image
    plt.subplot(1, 2, 2)
    plt.imshow(augmented)
    plt.title(title)
    plt.axis('off')  # Hide axes for clarity

    plt.show()

# Display the rotated image
show_images(original_image, rotated_image, 'Rotated Image (90 degrees)')

# Display the horizontally flipped image
show_images(original_image, flipped_horizontal, 'Flipped Horizontally')

# Display the vertically flipped image
show_images(original_image, flipped_vertical, 'Flipped Vertically')

# Display the zoomed image
show_images(original_image, zoomed_image, 'Zoomed Image (1.2x)')
